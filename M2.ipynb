# %% [markdown]
# ## DATA VISUALIZATION AND DATA ANALYSIS

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Dataset.csv')
df.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
df.columns
# Out:
# Index(['UDI', 'Product ID', 'Type', 'Air temperature [K]',
#        'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]',
#        'Tool wear [min]', 'Target', 'Failure Type'],
#       dtype='object')

# %%
del df['UDI']
del df['Product ID']

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='Type',data=df)
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df['Type'],color='red')

plt.subplot(1,2,2)
plt.hist(df['Rotational speed [rpm]'],color='blue')
# Out:
# (array([ 602., 4650., 3227.,  987.,  336.,  102.,   45.,   21.,   22.,
#            8.]),
#  array([1168. , 1339.8, 1511.6, 1683.4, 1855.2, 2027. , 2198.8, 2370.6,
#         2542.4, 2714.2, 2886. ]),
#  <BarContainer object of 10 artists>)

# %%
df.hist(figsize=(15,55),layout=(15,4), color='orange')
plt.show()

# %%
plt.boxplot(df["Process temperature [K]"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24328a1f010>,
#   <matplotlib.lines.Line2D at 0x24328a1f990>],
#  'caps': [<matplotlib.lines.Line2D at 0x24328a2c310>,
#   <matplotlib.lines.Line2D at 0x24328a13790>],
#  'boxes': [<matplotlib.lines.Line2D at 0x24328a1e850>],
#  'medians': [<matplotlib.lines.Line2D at 0x24328a2d150>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24328a2d910>],
#  'means': []}

# %%
    plt.scatter(df['Torque [Nm]'],df["Tool wear [min]"]) # scatter, plot, triplot, stackplot

# %%
df['Torque [Nm]'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.barplot(df['Air temperature [K]'], color='purple') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
k=['Type','Failure Type']
for i in k:
    df[i]=l.fit_transform(df[i]).astype(int)

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
# Out:
# <Axes: >

# %%
def plot(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return np.round(dataframe_pie/df.shape[0]*100,2)

plot(df, 'Failure Type')
# Out:
# Failure Type
# 1    96.52
# 0     1.12
# 3     0.95
# 2     0.78
# 5     0.45
# 4     0.18
# Name: count, dtype: float64
